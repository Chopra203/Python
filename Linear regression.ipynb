# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_excel ('Assessment 1 Dataset.xlsx')

# %%
df
# Out:
#               Squad  # Pl  90s  Gls   Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  \
# 0           Almería    29   38   49  439  155  35.3  11.55    4.08  0.11
# 1     Athletic Club    26   38   46  541  157  29.0  14.24    4.13  0.08
# 2   Atlético Madrid    27   38   68  538  195  36.2  14.16    5.13  0.12
# 3         Barcelona    29   38   69  570  187  32.8  15.00    4.92  0.12
# 4             Betis    30   38   43  411  138  33.6  10.82    3.63  0.09
# 5             Cádiz    38   38   29  390  108  27.7  10.26    2.84  0.06
# 6        Celta Vigo    26   38   41  470  160  34.0  12.37    4.21  0.08
# 7             Elche    32   38   30  400  124  31.0  10.53    3.26  0.07
# 8          Espanyol    33   38   51  417  151  36.2  10.97    3.97  0.11
# 9            Getafe    25   38   34  365  116  31.8   9.61    3.05  0.08
# 10           Girona    29   38   55  446  160  35.9  11.74    4.21  0.11
# 11         Mallorca    31   38   36  324  107  33.0   8.53    2.82  0.10
# 12          Osasuna    26   38   36  441  133  30.2  11.61    3.50  0.07
# 13   Rayo Vallecano    28   38   41  510  146  28.6  13.42    3.84  0.07
# 14      Real Madrid    26   38   73  634  206  32.5  16.68    5.42  0.10
# 15    Real Sociedad    30   38   47  465  173  37.2  12.24    4.55  0.10
# 16          Sevilla    35   38   47  463  141  30.5  12.18    3.71  0.09
# 17         Valencia    28   38   40  481  141  29.3  12.66    3.71  0.07
# 18       Valladolid    36   38   32  443  137  30.9  11.66    3.61  0.07
# 19       Villarreal    32   38   57  499  188  37.7  13.13    4.95  0.11
#
#     G/SoT  Dist  FK  PK  PKatt    xG  npxG  npxG/Sh  G-xG  np:G-xG
# 0    0.30  18.1  21   2      3  45.5  43.2     0.10   3.5      3.8
# 1    0.26  17.1  13   5      7  54.2  48.7     0.09  -8.2     -7.7
# 2    0.34  17.0   9   1      1  62.3  61.5     0.12   5.7      5.5
# 3    0.37  15.8  20   0      2  75.5  74.0     0.14  -6.5     -5.0
# 4    0.25  18.1  21   8      9  51.8  44.8     0.11  -8.8     -9.8
# 5    0.23  18.2  12   4      5  41.6  37.7     0.10 -12.6    -12.7
# 6    0.24  19.0  19   2      3  42.8  40.4     0.09  -1.8     -1.4
# 7    0.21  16.9  10   4      5  37.5  33.6     0.09  -7.5     -7.6
# 8    0.30  17.3  13   5      5  48.3  44.4     0.11   2.7      1.6
# 9    0.25  18.0  19   5      8  36.7  30.4     0.09  -2.7     -1.4
# 10   0.29  17.2   6   8      9  50.4  43.6     0.10   4.6      3.4
# 11   0.30  17.4   8   4      5  35.2  31.1     0.10   0.8      0.9
# 12   0.24  18.7   7   4      5  39.4  35.5     0.08  -3.4     -3.5
# 13   0.25  20.6  24   4      8  43.9  37.8     0.08  -2.9     -0.8
# 14   0.31  18.6  32   9     12  75.5  66.1     0.11  -2.5     -2.1
# 15   0.26  17.4  15   2      4  52.7  49.6     0.11  -5.7     -4.6
# 16   0.30  18.1  17   4      5  46.3  42.4     0.09   0.7      0.6
# 17   0.25  17.4  18   5      8  49.3  43.0     0.09  -9.3     -8.0
# 18   0.21  19.6  19   3      4  38.6  35.5     0.08  -6.6     -6.5
# 19   0.28  18.0  22   4      7  61.7  56.1     0.12  -4.7     -3.1

# %%
y = df.Gls
x = df.Sh.values.reshape(-1,1)

# %%
print(x.shape,y.shape)
# Out:
# (20, 1) (20,)

# %%
model = LinearRegression().fit(x,y)

# %%
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
print (r_sq)
# Out:
# 0.5935774862913115

# %%
y_pred = intercept+slope*x

# %%
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)

plt.plot(x,y_pred,c='red')




plt.gca().invert_yaxis

plt.xlabel('Goals Scored')
plt.ylabel('Total Shots')
plt.title('Evaluating relationship between goals scored and total shots')
# Out:
# Text(0.5, 1.0, 'Evaluating relationship between goals scored and total shots')
